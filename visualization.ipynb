# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import tables as tb
# %matplotlib notebook

# %%
fh=tb.open_file("output/main.py.2019-07-19+16:15/results.h5")

# %%
Ws=fh.root.W.read()
pi=fh.root.pi.read()
sigma=fh.root.sigma.read()
# Out:
# ---------------------------------------------------------------------------
# NoSuchNodeError                           Traceback (most recent call last)
# <ipython-input-13-00039efb2356> in <module>
#       2 pi=fh.root.pi.read()
#       3 sigma=fh.root.sigma.read()
# ----> 4 H=fh.root.H.read()
#
# ~/miniconda3/lib/python3.6/site-packages/tables-3.5.2-py3.6-macosx-10.7-x86_64.egg/tables/group.py in __getattr__(self, name)
#     837             self._g_add_children_names()
#     838             return self.__dict__[name]
# --> 839         return self._f_get_child(name)
#     840
#     841     def __setattr__(self, name, value):
#
# ~/miniconda3/lib/python3.6/site-packages/tables-3.5.2-py3.6-macosx-10.7-x86_64.egg/tables/group.py in _f_get_child(self, childname)
#     709         self._g_check_open()
#     710
# --> 711         self._g_check_has_child(childname)
#     712
#     713         childpath = join_path(self._v_pathname, childname)
#
# ~/miniconda3/lib/python3.6/site-packages/tables-3.5.2-py3.6-macosx-10.7-x86_64.egg/tables/group.py in _g_check_has_child(self, name)
#     396             raise NoSuchNodeError(
#     397                 "group ``%s`` does not have a child named ``%s``"
# --> 398                 % (self._v_pathname, name))
#     399         return node_type
#     400
#
# NoSuchNodeError: group ``/`` does not have a child named ``H``

# %%
plt.figure()
plt.plot(sigma)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(pi*100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig=plt.figure()
rows=np.sqrt(Ws.shape[-1])
cols=np.sqrt(Ws.shape[-1])
Ws.shape
D=int(np.sqrt(Ws.shape[-2]))
ind= -1
for i in range(Ws.shape[-1]):
    ax= fig.add_subplot(rows,cols,i+1)
    ax.imshow(Ws[ind,:,i].reshape((D,D)),interpolation='nearest')
    ax.axis('off')
# Out:
# <img src="data:image/png;base64,..." width="973">
