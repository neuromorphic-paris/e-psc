# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import tables as tb
# %matplotlib notebook

# %%
fh=tb.open_file("output/main.py.2019-07-22+14:12/results.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-313c2262086b> in <module>
# ----> 1 fh=tb.open_file("output/main.py.2019-07-22+15/43+1/results.h5")
#
# NameError: name 'tb' is not defined

# %%
Ws=fh.root.W.read()
pi=fh.root.pi.read()
sigma=fh.root.sigma.read()

# %%
plt.figure()
plt.plot(sigma)

# %%
plt.figure()
plt.plot(pi*100)

# %%
for ind in [0,1,2,5,10,-1]:
    fig=plt.figure(figsize=(10,10))
    rows=np.sqrt(Ws.shape[-1])
    cols=np.sqrt(Ws.shape[-1])
    Ws.shape
    D=int(np.sqrt(Ws.shape[-2]))
#     ind= 0
    for i in range(Ws.shape[-1]):
        ax= fig.add_subplot(rows,cols,i+1)
        ax.imshow(Ws[ind,:,i].reshape((D,D)),interpolation='nearest')
        ax.axis('off')

# %%
sigma
# Out:
# array([0.26603653, 0.22911777, 0.21854551, 0.21392425, 0.21332295,
#        0.21161851, 0.21063354, 0.20895796, 0.20712773, 0.2051814 ,
#        0.20264075, 0.20195331, 0.20065068, 0.20038148, 0.19961401,
#        0.19834347, 0.19735127, 0.19675176, 0.19578116, 0.19530727,
#        0.19463719, 0.19354707, 0.19338943, 0.19286918, 0.1923298 ,
#        0.19173982, 0.19140058, 0.1907005 , 0.19017481, 0.18970548,
#        0.18916703, 0.18913349, 0.18797555, 0.18777636, 0.18763337,
#        0.18705683, 0.18685853, 0.18648739, 0.18584084, 0.18538492,
#        0.18505114, 0.18466436, 0.18416082, 0.18376708, 0.18338471,
#        0.18315679, 0.18263372, 0.1822429 , 0.18206884, 0.18169801,
#        0.1814447 , 0.1809873 , 0.1805843 , 0.18030361, 0.18001601,
#        0.17963928, 0.17931949, 0.17921959, 0.17889324, 0.17855425,
#        0.17832534, 0.17794606, 0.17783067, 0.17755962, 0.17720141,
#        0.17700481, 0.17682354, 0.17660095, 0.17633265, 0.17613294,
#        0.175883  , 0.17567228, 0.17555394, 0.1753129 , 0.17518034,
#        0.17497736, 0.17483448, 0.17465221, 0.17448987, 0.1743435 ,
#        0.17421217, 0.1740918 , 0.17395631, 0.17384825, 0.17375497,
#        0.17365747, 0.17357404, 0.17349548, 0.17342318, 0.17335501,
#        0.17329949, 0.1732445 , 0.1731986 , 0.17315782, 0.17312331,
#        0.17309384, 0.17306952, 0.17305422, 0.17304514, 0.1730387 ,
#        0.17303029, 0.1730249 , 0.17301873, 0.17301111, 0.1730025 ,
#        0.17299537, 0.17298754, 0.17297624, 0.17295933, 0.17294616,
#        0.17293724, 0.17292825, 0.17291909, 0.17291554, 0.17291226,
#        0.17290837, 0.1729067 , 0.17290732, 0.17290533, 0.17290523])

# %%
pi
# Out:
# array([0.00707767, 0.00637883, 0.00604771, 0.00574286, 0.00553478,
#        0.00522826, 0.00494447, 0.00462455, 0.00437429, 0.00426627,
#        0.00420128, 0.00418548, 0.00416036, 0.00416763, 0.00414753,
#        0.00414445, 0.004152  , 0.00414523, 0.00414916, 0.00414251,
#        0.0041487 , 0.00415331, 0.00416008, 0.00415783, 0.00416637,
#        0.00417213, 0.00417521, 0.00417998, 0.00417572, 0.004182  ,
#        0.00418283, 0.00418748, 0.00418663, 0.00419466, 0.00419367,
#        0.00419824, 0.00420263, 0.00420484, 0.0042123 , 0.00420647,
#        0.00420753, 0.00421617, 0.00422426, 0.0042224 , 0.00422161,
#        0.00422705, 0.004227  , 0.00423312, 0.00423476, 0.00423402,
#        0.00423575, 0.00423846, 0.00424251, 0.0042389 , 0.00424441,
#        0.00424927, 0.00425424, 0.00425162, 0.00425121, 0.00425107,
#        0.00426177, 0.00426061, 0.00426404, 0.00426832, 0.00427128,
#        0.00427351, 0.00427514, 0.00428254, 0.00428267, 0.00428482,
#        0.00428713, 0.00428479, 0.00428868, 0.00429036, 0.00429485,
#        0.00429973, 0.00430358, 0.00430822, 0.00431043, 0.00431212,
#        0.0043167 , 0.00431847, 0.00432006, 0.00432278, 0.00432533,
#        0.00433028, 0.00433142, 0.00433585, 0.00434024, 0.00434455,
#        0.00434875, 0.00435437, 0.00435939, 0.00436714, 0.00437662,
#        0.00438708, 0.00439936, 0.00440711, 0.00440935, 0.00441113,
#        0.00441331, 0.00441519, 0.00441857, 0.00442254, 0.0044267 ,
#        0.00442947, 0.00443283, 0.00443718, 0.00444279, 0.00444793,
#        0.00445239, 0.00445687, 0.00446143, 0.00446431, 0.00446584,
#        0.00446792, 0.00447041, 0.00447319, 0.00447595, 0.00447724])
